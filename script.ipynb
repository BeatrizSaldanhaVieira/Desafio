-- %% [markdown]
-- # [DesafioFullStack]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [DesafioFullStack]    Script Date: 20/03/2025 14:57:25 ******/
CREATE DATABASE [DesafioFullStack]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'DesafioFullStack', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL13.SQLEXPRESS\MSSQL\DATA\DesafioFullStack.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'DesafioFullStack_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL13.SQLEXPRESS\MSSQL\DATA\DesafioFullStack_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
GO
ALTER DATABASE [DesafioFullStack] SET COMPATIBILITY_LEVEL = 130
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [DesafioFullStack].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [DesafioFullStack] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [DesafioFullStack] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [DesafioFullStack] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [DesafioFullStack] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [DesafioFullStack] SET ARITHABORT OFF 
GO
ALTER DATABASE [DesafioFullStack] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [DesafioFullStack] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [DesafioFullStack] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [DesafioFullStack] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [DesafioFullStack] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [DesafioFullStack] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [DesafioFullStack] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [DesafioFullStack] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [DesafioFullStack] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [DesafioFullStack] SET  ENABLE_BROKER 
GO
ALTER DATABASE [DesafioFullStack] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [DesafioFullStack] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [DesafioFullStack] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [DesafioFullStack] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [DesafioFullStack] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [DesafioFullStack] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [DesafioFullStack] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [DesafioFullStack] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [DesafioFullStack] SET  MULTI_USER 
GO
ALTER DATABASE [DesafioFullStack] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [DesafioFullStack] SET DB_CHAINING OFF 
GO
ALTER DATABASE [DesafioFullStack] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [DesafioFullStack] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [DesafioFullStack] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [DesafioFullStack] SET QUERY_STORE = OFF
GO
USE [DesafioFullStack]
GO
ALTER DATABASE SCOPED CONFIGURATION SET LEGACY_CARDINALITY_ESTIMATION = OFF;
GO
ALTER DATABASE SCOPED CONFIGURATION SET MAXDOP = 0;
GO
ALTER DATABASE SCOPED CONFIGURATION SET PARAMETER_SNIFFING = ON;
GO
ALTER DATABASE SCOPED CONFIGURATION SET QUERY_OPTIMIZER_HOTFIXES = OFF;
GO

-- %% [markdown]
-- # [dbo].[Empresa]

-- %%
USE [DesafioFullStack]
GO

-- %%
/****** Object:  Table [dbo].[Empresa]    Script Date: 20/03/2025 14:57:26 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Empresa](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CNPJ] [varchar](18) NOT NULL,
	[NomeFantasia] [varchar](255) NOT NULL,
	[CEP] [varchar](8) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[CNPJ] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[EmpresaFornecedor]

-- %%
/****** Object:  Table [dbo].[EmpresaFornecedor]    Script Date: 20/03/2025 14:57:26 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EmpresaFornecedor](
	[EmpresaId] [int] NOT NULL,
	[FornecedorId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[EmpresaId] ASC,
	[FornecedorId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Fornecedor]

-- %%
/****** Object:  Table [dbo].[Fornecedor]    Script Date: 20/03/2025 14:57:26 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Fornecedor](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CNPJ_CPF] [varchar](18) NOT NULL,
	[Nome] [varchar](255) NOT NULL,
	[Email] [varchar](255) NOT NULL,
	[CEP] [varchar](8) NOT NULL,
	[TipoPessoa] [varchar](1) NULL,
	[RG] [varchar](20) NULL,
	[DataNascimento] [date] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [CK_Fornecedor_CNPJ_CPF] UNIQUE NONCLUSTERED 
(
	[CNPJ_CPF] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[CNPJ_CPF] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__EmpresaFo__Empre__2B3F6F97]

-- %%
ALTER TABLE [dbo].[EmpresaFornecedor]  WITH CHECK ADD FOREIGN KEY([EmpresaId])
REFERENCES [dbo].[Empresa] ([Id])
GO

-- %% [markdown]
-- # [FK__EmpresaFo__Forne__2C3393D0]

-- %%
ALTER TABLE [dbo].[EmpresaFornecedor]  WITH CHECK ADD FOREIGN KEY([FornecedorId])
REFERENCES [dbo].[Fornecedor] ([Id])
GO

-- %% [markdown]
-- # [CK__Fornecedo__TipoP__286302EC]

-- %%
ALTER TABLE [dbo].[Fornecedor]  WITH CHECK ADD CHECK  (([TipoPessoa]='J' OR [TipoPessoa]='F'))
GO

-- %% [markdown]
-- # [DesafioFullStack]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [DesafioFullStack] SET  READ_WRITE 
GO
